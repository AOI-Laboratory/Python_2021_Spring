# %% [markdown]
# ---
#
#
# Author: Eugene Su
#
# Email: <su.eugene@gmail.com>
#
# https://sites.google.com/view/smartrobot/lab
#
#
# ---

# %% [markdown]
# 使用magic command 顯示tensorflow版本資訊

# %%
# !pip show tensorflow

# %% [markdown]
# 使用magic command查看tensorflow-gpu套件是否已經安裝

# %%
# !pip show tensorflow-gpu

# %% [markdown]
# 使用magic command安裝tensorflow-gpu

# %%
# !pip install tensorflow-gpu

# %% [markdown]
# 使用magic command查看Colab環境已安裝之Python套件

# %%
# !pip list

# %% [markdown]
# Triple quotes

# %%
x = '''one line
two line
three line'''

print(x)

# %% [markdown]
# Triple quotes

# %%
y = """one line
two line
three line"""

print(y)

# %% [markdown]
# 三次換行之列印

# %%
  text1 = 'Pi'
  text2 = 'is'
  pi = 3.141592653
  print(text1)
  print(text2)
  print(pi)

# %% [markdown]
# 一次換行之列印

# %%
text1 = 'Pi'
text2 = 'is'
pi = 3.141592653
print(text1, text2, pi)

# %% [markdown]
# str.format(*args, **kwargs)
#
#
# ---
#
# replacement_field ::=  "{" [field_name] ["!" conversion] [":" format_spec] "}"
#
# field_name        ::=  arg_name ("." attribute_name | "[" element_index "]")*
#
# arg_name          ::=  [identifier | digit+]
#
# attribute_name    ::=  identifier
#
# element_index     ::=  digit+ | index_string
#
# index_string      ::=  <any source character except "]"> +
#
# conversion        ::=  "r" | "s" | "a"
#
# format_spec       ::=  \<described in the next section>
#
#
# ---

# %% [markdown]
# The general form of a standard format specifier is:
#
# format_spec ::=  [[fill]align][sign][#][0][width][,][.precision][type]
#
# fill        ::=  \<any character>
#
# align       ::=  "<" | ">" | "=" | "^"
#
# sign        ::=  "+" | "-" | " "
#
# width       ::=  integer
#
# precision   ::=  integer
#
# type        ::=  "b" | "c" | "d" | "e" | "E" | "f" | "F" | "g" | "G" | "n" | "o" | "s" | "x" | "X" | "%"

# %%
pi = 3.141592653
print('Pi is {}'.format(pi))
print('Pi is {:.2f}'.format(pi))
print('Pi is {:05.2f}'.format(pi))

# %%
num1 = 5
num2 = 22
print('number is {:>3d}, square is {:04d}'.format(num1, num1 * num1))
print('number is {:>3d}, square is {:04d}'.format(num2, num2 * num2))
