# %% [markdown]
# ---
#
#
# Author: Eugene Su
#
# Email: <su.eugene@gmail.com>
#
# https://sites.google.com/view/smartrobot/lab
#
#
# ---

# %% [markdown]
# str.format(*args, **kwargs)
#
#
# ---
#
# replacement_field ::=  "{" [field_name] ["!" conversion] [":" format_spec] "}"
#
# field_name        ::=  arg_name ("." attribute_name | "[" element_index "]")*
#
# arg_name          ::=  [identifier | digit+]
#
# attribute_name    ::=  identifier
#
# element_index     ::=  digit+ | index_string
#
# index_string      ::=  <any source character except "]"> +
#
# conversion        ::=  "r" | "s" | "a"
#
# format_spec       ::=  \<described in the next section>
#
#
# ---

# %% [markdown]
# The general form of a standard format specifier is:
#
# format_spec ::=  [[fill]align][sign][#][0][width][,][.precision][type]
#
# fill            ::=  \<any character>
#
# align       ::=  "<" | ">" | "=" | "^"
#
# sign        ::=  "+" | "-" | " "
#
# width       ::=  integer
#
# precision   ::=  integer
#
# type        ::=  "b" | "c" | "d" | "e" | "E" | "f" | "F" | "g" | "G" | "n" | "o" | "s" | "x" | "X" | "%"
#
#
# ---

# %%
x = 1
sl_1 = x << 1
sl_2 = x << 2
sl_3 = x << 3

print('x = 0b{:b}'.format(x))
print('shift left 1 of x = ob{:b} or {}'.format(sl_1, sl_1))
print('shift left 2 of x = ob{0:b} or {0}'.format(sl_2))
print('shift left 3 of x = ob{0:b} or {0}'.format(sl_3))
# Out:
# x = 0b1
# shift left 1 of x = ob10 or 2
# shift left 2 of x = ob100 or 4
# shift left 3 of x = ob1000 or 8

# %% [markdown]
# 2 ** 31是2<sup>31</sup>
#
# ---

# %%
import time

start = time.time()
for i in range((2 ** 31) + 0, (2 ** 31) + 20000000):
    x = i << 1

end = time.time()
print('Spent time of shift left in large number = {}'.format(end - start))
# Out:
# Spent time of shift left in large number = 2.579423666000366

# %%
import time

start = time.time()
for i in range((2 ** 31) + 0, (2 ** 31) + 20000000):
    x = i * 2

end = time.time()
print('Spent times of multiplier in large number = {}'.format(end - start))
# Out:
# Spent times of multiplier in large number = 2.724045753479004

# %%
import time

start = time.time()
for i in range(0, 20000000):
    x = i << 1

end = time.time()
print('Spent time of shift left in small number = {}'.format(end - start))
# Out:
# Spent time of shift left in small number = 2.4551446437835693

# %%
import time

start = time.time()
for i in range(0, 20000000):
    x = i * 2

end = time.time()
print('Spent time of multiplier in small number = {}'.format(end - start))
# Out:
# Spent time of multiplier in small number = 2.377171277999878
