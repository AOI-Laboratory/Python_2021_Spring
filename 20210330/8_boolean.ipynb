# %% [markdown]
# ---
#
#
# Author: Eugene Su
#
# Email: <su.eugene@gmail.com>
#
# https://sites.google.com/view/smartrobot/lab
#
#
# ---

# %% [markdown]
# class bool([x]): Return a Boolean value, i.e. one of True or False. x is converted using the standard truth testing procedure. If x is false or omitted, this returns False; otherwise it returns True. The bool class is a subclass of int. It cannot be subclassed further. Its only instances are False and True.
#
# ---

# %%
x = 0

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = 0, is False. bool(x) = False

# %%
x = 1

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = 1, is True. bool(x) = True

# %%
x = 2

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = 2, is True. bool(x) = True

# %%
x = -1

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = -1, is True. bool(x) = True

# %%
x = 0.1

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = 0.1, is True. bool(x) = True

# %%
x = ''

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = , is False. bool(x) = False

# %%
x = 'x'

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = x, is True. bool(x) = True

# %%
x = None

if x:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = None, is False. bool(x) = False

# %% [markdown]
# 下列範例演示語法正確，但程式結果不如預期的邏輯錯誤。
#
# ---

# %%
true = 1
false = ''
x = 2
if x == true:
    print('x = {}, is True. bool(x) = {}'.format(x, bool(x)))
else:
    print('x = {}, is False. bool(x) = {}'.format(x, bool(x)))
# Out:
# x = 2, is False. bool(x) = True
